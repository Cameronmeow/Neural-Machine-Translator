# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.4.1)
# Requirement already satisfied: absl-py in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras) (23.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from optree->keras) (4.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\debas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install numpy
# !pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.25.2)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\debas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Collecting tensorflow
#   Downloading tensorflow-2.17.0-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Collecting tensorflow-intel==2.17.0 (from tensorflow)
#   Downloading tensorflow_intel-2.17.0-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached h5py-3.11.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.3)
# Collecting requests<3,>=2.21.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.9.0)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached grpcio-1.64.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.0->tensorflow)
#   Downloading tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.2.0 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.17.0->tensorflow)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.25.2)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached wheel-0.43.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting rich (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading optree-0.12.1-cp311-cp311-win_amd64.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ------------------------------- ------ 41.0/48.7 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 48.7/48.7 kB 818.0 kB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\debas\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.17.0-cp311-cp311-win_amd64.whl (2.0 kB)
# Downloading tensorflow_intel-2.17.0-cp311-cp311-win_amd64.whl (385.0 MB)
#    ---------------------------------------- 0.0/385.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/385.0 MB 991.0 kB/s eta 0:06:29
#    ---------------------------------------- 0.1/385.0 MB 1.3 MB/s eta 0:04:54
#    ---------------------------------------- 0.2/385.0 MB 1.2 MB/s eta 0:05:14
#    ---------------------------------------- 0.2/385.0 MB 1.1 MB/s eta 0:06:00
#    ---------------------------------------- 0.3/385.0 MB 1.2 MB/s eta 0:05:30
#    ---------------------------------------- 0.3/385.0 MB 1.2 MB/s eta 0:05:23
#    ---------------------------------------- 0.3/385.0 MB 1.1 MB/s eta 0:05:39
#    ---------------------------------------- 0.4/385.0 MB 1.1 MB/s eta 0:05:44
#    ---------------------------------------- 0.5/385.0 MB 1.1 MB/s eta 0:05:38
#    ---------------------------------------- 0.6/385.0 MB 1.2 MB/s eta 0:05:21
#    ---------------------------------------- 0.6/385.0 MB 1.2 MB/s eta 0:05:23
#    ---------------------------------------- 0.7/385.0 MB 1.3 MB/s eta 0:04:58
#    ---------------------------------------- 0.8/385.0 MB 1.3 MB/s eta 0:04:50
#    ---------------------------------------- 0.8/385.0 MB 1.3 MB/s eta 0:04:50
#    ---------------------------------------- 0.9/385.0 MB 1.4 MB/s eta 0:04:41
#    ---------------------------------------- 1.0/385.0 MB 1.4 MB/s eta 0:04:42
#    ---------------------------------------- 1.1/385.0 MB 1.4 MB/s eta 0:04:32
#    ---------------------------------------- 1.2/385.0 MB 1.4 MB/s eta 0:04:31
#    ---------------------------------------- 1.3/385.0 MB 1.5 MB/s eta 0:04:24
#    ---------------------------------------- 1.4/385.0 MB 1.5 MB/s eta 0:04:20
#    ---------------------------------------- 1.5/385.0 MB 1.5 MB/s eta 0:04:14
#    ---------------------------------------- 1.5/385.0 MB 1.4 MB/s eta 0:04:27
#    ---------------------------------------- 1.6/385.0 MB 1.5 MB/s eta 0:04:18
#    ---------------------------------------- 1.8/385.0 MB 1.6 MB/s eta 0:04:07
#    ---------------------------------------- 1.8/385.0 MB 1.6 MB/s eta 0:04:06
#    ---------------------------------------- 1.8/385.0 MB 1.6 MB/s eta 0:04:06
#    ---------------------------------------- 2.0/385.0 MB 1.6 MB/s eta 0:04:07
#    ---------------------------------------- 2.0/385.0 MB 1.5 MB/s eta 0:04:19
#    ---------------------------------------- 2.1/385.0 MB 1.6 MB/s eta 0:04:07
#    ---------------------------------------- 2.1/385.0 MB 1.6 MB/s eta 0:04:07
#    ---------------------------------------- 2.3/385.0 MB 1.5 MB/s eta 0:04:08
#    ---------------------------------------- 2.3/385.0 MB 1.5 MB/s eta 0:04:08
#    ---------------------------------------- 2.4/385.0 MB 1.5 MB/s eta 0:04:08
#    ---------------------------------------- 2.5/385.0 MB 1.6 MB/s eta 0:04:06
#    ---------------------------------------- 2.5/385.0 MB 1.5 MB/s eta 0:04:08
#    ---------------------------------------- 2.7/385.0 MB 1.6 MB/s eta 0:04:03
#    ---------------------------------------- 2.8/385.0 MB 1.6 MB/s eta 0:04:06
#    ---------------------------------------- 2.8/385.0 MB 1.6 MB/s eta 0:03:59
#    ---------------------------------------- 2.9/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.0/385.0 MB 1.6 MB/s eta 0:03:58
#    ---------------------------------------- 3.1/385.0 MB 1.6 MB/s eta 0:03:57
#    ---------------------------------------- 3.2/385.0 MB 1.6 MB/s eta 0:03:58
#    ---------------------------------------- 3.3/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.4/385.0 MB 1.6 MB/s eta 0:03:53
#    ---------------------------------------- 3.4/385.0 MB 1.6 MB/s eta 0:03:59
#    ---------------------------------------- 3.5/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.6/385.0 MB 1.6 MB/s eta 0:04:03
#    ---------------------------------------- 3.6/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.6/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.6/385.0 MB 1.6 MB/s eta 0:04:00
#    ---------------------------------------- 3.7/385.0 MB 1.5 MB/s eta 0:04:10
#    ---------------------------------------- 3.7/385.0 MB 1.5 MB/s eta 0:04:11
#    ---------------------------------------- 3.8/385.0 MB 1.5 MB/s eta 0:04:20
#    ---------------------------------------- 4.0/385.0 MB 1.5 MB/s eta 0:04:09
#    ---------------------------------------- 4.0/385.0 MB 1.5 MB/s eta 0:04:13
#    ---------------------------------------- 4.0/385.0 MB 1.5 MB/s eta 0:04:15
#    ---------------------------------------- 4.0/385.0 MB 1.5 MB/s eta 0:04:20
#    ---------------------------------------- 4.2/385.0 MB 1.5 MB/s eta 0:04:16
#    ---------------------------------------- 4.2/385.0 MB 1.5 MB/s eta 0:04:16
#    ---------------------------------------- 4.2/385.0 MB 1.5 MB/s eta 0:04:16
#    ---------------------------------------- 4.2/385.0 MB 1.5 MB/s eta 0:04:16
#    ---------------------------------------- 4.4/385.0 MB 1.5 MB/s eta 0:04:22
#    ---------------------------------------- 4.4/385.0 MB 1.4 MB/s eta 0:04:24
#    ---------------------------------------- 4.5/385.0 MB 1.5 MB/s eta 0:04:19
#    ---------------------------------------- 4.5/385.0 MB 1.5 MB/s eta 0:04:19
#    ---------------------------------------- 4.7/385.0 MB 1.5 MB/s eta 0:04:17
#    ---------------------------------------- 4.7/385.0 MB 1.5 MB/s eta 0:04:17
#     --------------------------------------- 4.9/385.0 MB 1.5 MB/s eta 0:04:17
#     --------------------------------------- 4.9/385.0 MB 1.5 MB/s eta 0:04:15
#     --------------------------------------- 5.0/385.0 MB 1.5 MB/s eta 0:04:17
#     --------------------------------------- 5.0/385.0 MB 1.5 MB/s eta 0:04:17
#     --------------------------------------- 5.0/385.0 MB 1.4 MB/s eta 0:04:24
#     --------------------------------------- 5.2/385.0 MB 1.5 MB/s eta 0:04:17
#     --------------------------------------- 5.2/385.0 MB 1.5 MB/s eta 0:04:18
#     --------------------------------------- 5.4/385.0 MB 1.5 MB/s eta 0:04:12
#     --------------------------------------- 5.4/385.0 MB 1.5 MB/s eta 0:04:12
#     --------------------------------------- 5.6/385.0 MB 1.5 MB/s eta 0:04:09
#     --------------------------------------- 5.6/385.0 MB 1.5 MB/s eta 0:04:09
#     --------------------------------------- 5.8/385.0 MB 1.5 MB/s eta 0:04:08
#     --------------------------------------- 5.8/385.0 MB 1.5 MB/s eta 0:04:11
#     --------------------------------------- 5.9/385.0 MB 1.5 MB/s eta 0:04:08
#     --------------------------------------- 6.0/385.0 MB 1.5 MB/s eta 0:04:09
#     --------------------------------------- 6.2/385.0 MB 1.6 MB/s eta 0:04:04
#     --------------------------------------- 6.3/385.0 MB 1.6 MB/s eta 0:04:04
#     --------------------------------------- 6.3/385.0 MB 1.6 MB/s eta 0:04:04
#     --------------------------------------- 6.3/385.0 MB 1.6 MB/s eta 0:04:04
#     --------------------------------------- 6.4/385.0 MB 1.5 MB/s eta 0:04:07
#     --------------------------------------- 6.5/385.0 MB 1.5 MB/s eta 0:04:05
#     --------------------------------------- 6.7/385.0 MB 1.6 MB/s eta 0:04:01
#     --------------------------------------- 6.7/385.0 MB 1.6 MB/s eta 0:04:02
#     --------------------------------------- 6.9/385.0 MB 1.6 MB/s eta 0:04:01
#     --------------------------------------- 6.9/385.0 MB 1.6 MB/s eta 0:04:02
#     --------------------------------------- 7.1/385.0 MB 1.6 MB/s eta 0:03:58
#     --------------------------------------- 7.1/385.0 MB 1.6 MB/s eta 0:03:59
#     --------------------------------------- 7.3/385.0 MB 1.6 MB/s eta 0:03:57
#     --------------------------------------- 7.3/385.0 MB 1.6 MB/s eta 0:03:57
#     --------------------------------------- 7.4/385.0 MB 1.6 MB/s eta 0:03:59
#     --------------------------------------- 7.6/385.0 MB 1.6 MB/s eta 0:03:55
#     --------------------------------------- 7.7/385.0 MB 1.6 MB/s eta 0:03:53
#     --------------------------------------- 7.8/385.0 MB 1.6 MB/s eta 0:03:51
#     --------------------------------------- 7.8/385.0 MB 1.6 MB/s eta 0:03:51
#     --------------------------------------- 7.9/385.0 MB 1.6 MB/s eta 0:03:54
#     --------------------------------------- 7.9/385.0 MB 1.6 MB/s eta 0:03:54
#     --------------------------------------- 8.1/385.0 MB 1.6 MB/s eta 0:03:52
#     --------------------------------------- 8.1/385.0 MB 1.6 MB/s eta 0:03:52
#     --------------------------------------- 8.2/385.0 MB 1.6 MB/s eta 0:03:54
#     --------------------------------------- 8.3/385.0 MB 1.6 MB/s eta 0:03:53
#     --------------------------------------- 8.4/385.0 MB 1.6 MB/s eta 0:03:52
#     --------------------------------------- 8.4/385.0 MB 1.6 MB/s eta 0:03:52
#     --------------------------------------- 8.7/385.0 MB 1.7 MB/s eta 0:03:48
#     --------------------------------------- 8.8/385.0 MB 1.6 MB/s eta 0:03:49
#     --------------------------------------- 9.0/385.0 MB 1.7 MB/s eta 0:03:45
#     --------------------------------------- 9.0/385.0 MB 1.7 MB/s eta 0:03:45
#     --------------------------------------- 9.3/385.0 MB 1.7 MB/s eta 0:03:42
#     --------------------------------------- 9.3/385.0 MB 1.7 MB/s eta 0:03:44
#     --------------------------------------- 9.6/385.0 MB 1.7 MB/s eta 0:03:39
#     --------------------------------------- 9.6/385.0 MB 1.7 MB/s eta 0:03:39
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:36
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:35
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:35
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:35
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:42
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:42
#    - -------------------------------------- 9.9/385.0 MB 1.7 MB/s eta 0:03:42
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.0/385.0 MB 1.7 MB/s eta 0:03:44
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.1/385.0 MB 1.6 MB/s eta 0:04:02
#    - -------------------------------------- 10.2/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 10.2/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 10.2/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 10.2/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.5 MB/s eta 0:04:17
#    - -------------------------------------- 10.3/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.3/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.3/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.5/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.5/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.5/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.6/385.0 MB 1.4 MB/s eta 0:04:32
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:31
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.7/385.0 MB 1.4 MB/s eta 0:04:30
#    - -------------------------------------- 10.8/385.0 MB 1.3 MB/s eta 0:04:39
#    - -------------------------------------- 10.9/385.0 MB 1.3 MB/s eta 0:04:39
#    - -------------------------------------- 10.9/385.0 MB 1.3 MB/s eta 0:04:39
#    - -------------------------------------- 10.9/385.0 MB 1.3 MB/s eta 0:04:39
#    - -------------------------------------- 11.0/385.0 MB 1.3 MB/s eta 0:04:42
#    - -------------------------------------- 11.1/385.0 MB 1.3 MB/s eta 0:04:41
#    - -------------------------------------- 11.1/385.0 MB 1.3 MB/s eta 0:04:41
#    - -------------------------------------- 11.1/385.0 MB 1.3 MB/s eta 0:04:41
#    - -------------------------------------- 11.1/385.0 MB 1.3 MB/s eta 0:04:41
#    - -------------------------------------- 11.1/385.0 MB 1.3 MB/s eta 0:04:48
#    - -------------------------------------- 11.2/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.4/385.0 MB 1.3 MB/s eta 0:04:45
#    - -------------------------------------- 11.9/385.0 MB 1.2 MB/s eta 0:05:00
#    - -------------------------------------- 12.0/385.0 MB 1.2 MB/s eta 0:05:03
#    - -------------------------------------- 12.2/385.0 MB 1.3 MB/s eta 0:04:56
#    - -------------------------------------- 12.2/385.0 MB 1.3 MB/s eta 0:04:56
#    - -------------------------------------- 12.3/385.0 MB 1.3 MB/s eta 0:04:58
#    - -------------------------------------- 12.3/385.0 MB 1.3 MB/s eta 0:04:58
#    - -------------------------------------- 12.6/385.0 MB 1.3 MB/s eta 0:04:55
#    - -------------------------------------- 12.6/385.0 MB 1.3 MB/s eta 0:04:55
#    - -------------------------------------- 12.9/385.0 MB 1.3 MB/s eta 0:04:53
#    - -------------------------------------- 13.0/385.0 MB 1.3 MB/s eta 0:04:52
#    - -------------------------------------- 13.2/385.0 MB 1.3 MB/s eta 0:04:49
#    - -------------------------------------- 13.4/385.0 MB 1.3 MB/s eta 0:04:44
#    - -------------------------------------- 13.6/385.0 MB 1.3 MB/s eta 0:04:42
#    - -------------------------------------- 13.9/385.0 MB 1.4 MB/s eta 0:04:33
#    - -------------------------------------- 14.2/385.0 MB 1.4 MB/s eta 0:04:27
#    - -------------------------------------- 14.5/385.0 MB 1.4 MB/s eta 0:04:17
#    - -------------------------------------- 14.6/385.0 MB 1.4 MB/s eta 0:04:17
#    - -------------------------------------- 14.6/385.0 MB 1.4 MB/s eta 0:04:17
#    - -------------------------------------- 14.8/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 15.0/385.0 MB 1.5 MB/s eta 0:04:13
#    - -------------------------------------- 15.1/385.0 MB 1.5 MB/s eta 0:04:14
#    - -------------------------------------- 15.2/385.0 MB 1.5 MB/s eta 0:04:09
#    - -------------------------------------- 15.3/385.0 MB 1.5 MB/s eta 0:04:10
#    - -------------------------------------- 15.6/385.0 MB 1.5 MB/s eta 0:04:09
#    - -------------------------------------- 15.9/385.0 MB 1.5 MB/s eta 0:04:04
#    - -------------------------------------- 16.1/385.0 MB 1.5 MB/s eta 0:04:01
#    - -------------------------------------- 16.3/385.0 MB 1.6 MB/s eta 0:03:58
#    - -------------------------------------- 16.7/385.0 MB 1.6 MB/s eta 0:03:51
#    - -------------------------------------- 17.0/385.0 MB 1.6 MB/s eta 0:03:48
#    - -------------------------------------- 17.2/385.0 MB 1.6 MB/s eta 0:03:47
#    - -------------------------------------- 17.3/385.0 MB 1.6 MB/s eta 0:03:47
#    - -------------------------------------- 17.4/385.0 MB 1.6 MB/s eta 0:03:45
#    - -------------------------------------- 17.5/385.0 MB 1.6 MB/s eta 0:03:47
#    - -------------------------------------- 17.6/385.0 MB 1.6 MB/s eta 0:03:44
#    - -------------------------------------- 17.7/385.0 MB 1.6 MB/s eta 0:03:47
#    - -------------------------------------- 17.9/385.0 MB 1.6 MB/s eta 0:03:45
#    - -------------------------------------- 18.0/385.0 MB 1.6 MB/s eta 0:03:46
#    - -------------------------------------- 18.2/385.0 MB 1.7 MB/s eta 0:03:41
#    - -------------------------------------- 18.3/385.0 MB 1.7 MB/s eta 0:03:42
#    - -------------------------------------- 18.6/385.0 MB 1.7 MB/s eta 0:03:37
#    - -------------------------------------- 18.8/385.0 MB 1.7 MB/s eta 0:03:35
#    - -------------------------------------- 18.9/385.0 MB 1.7 MB/s eta 0:03:35
#    - -------------------------------------- 19.2/385.0 MB 1.7 MB/s eta 0:03:33
#    -- ------------------------------------- 19.4/385.0 MB 1.7 MB/s eta 0:03:33
#    -- ------------------------------------- 19.6/385.0 MB 1.8 MB/s eta 0:03:29
#    -- ------------------------------------- 20.0/385.0 MB 1.8 MB/s eta 0:03:27
#    -- ------------------------------------- 20.2/385.0 MB 1.8 MB/s eta 0:03:18
#    -- ------------------------------------- 20.5/385.0 MB 2.3 MB/s eta 0:02:40
#    -- ------------------------------------- 20.7/385.0 MB 2.6 MB/s eta 0:02:22
#    -- ------------------------------------- 21.0/385.0 MB 2.7 MB/s eta 0:02:16
#    -- ------------------------------------- 21.4/385.0 MB 3.2 MB/s eta 0:01:53
#    -- ------------------------------------- 21.6/385.0 MB 3.3 MB/s eta 0:01:52
#    -- ------------------------------------- 21.8/385.0 MB 4.2 MB/s eta 0:01:28
#    -- ------------------------------------- 22.1/385.0 MB 4.1 MB/s eta 0:01:29
#    -- ------------------------------------- 22.5/385.0 MB 4.3 MB/s eta 0:01:25
#    -- ------------------------------------- 22.8/385.0 MB 4.4 MB/s eta 0:01:22
#    -- ------------------------------------- 23.1/385.0 MB 4.6 MB/s eta 0:01:20
#    -- ------------------------------------- 23.3/385.0 MB 4.6 MB/s eta 0:01:20
#    -- ------------------------------------- 23.7/385.0 MB 4.7 MB/s eta 0:01:18
#    -- ------------------------------------- 23.9/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 24.0/385.0 MB 4.6 MB/s eta 0:01:19
#    -- ------------------------------------- 24.1/385.0 MB 4.5 MB/s eta 0:01:21
#    -- ------------------------------------- 24.1/385.0 MB 4.5 MB/s eta 0:01:22
#    -- ------------------------------------- 24.2/385.0 MB 4.4 MB/s eta 0:01:22
#    -- ------------------------------------- 24.4/385.0 MB 4.4 MB/s eta 0:01:23
#    -- ------------------------------------- 24.8/385.0 MB 4.5 MB/s eta 0:01:20
#    -- ------------------------------------- 24.9/385.0 MB 4.5 MB/s eta 0:01:21
#    -- ------------------------------------- 25.1/385.0 MB 4.5 MB/s eta 0:01:20
#    -- ------------------------------------- 25.4/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 25.5/385.0 MB 4.6 MB/s eta 0:01:19
#    -- ------------------------------------- 25.7/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 26.0/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 26.2/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 26.5/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 26.7/385.0 MB 4.6 MB/s eta 0:01:18
#    -- ------------------------------------- 26.9/385.0 MB 4.6 MB/s eta 0:01:19
#    -- ------------------------------------- 27.1/385.0 MB 4.5 MB/s eta 0:01:19
#    -- ------------------------------------- 27.4/385.0 MB 4.5 MB/s eta 0:01:19
#    -- ------------------------------------- 27.6/385.0 MB 4.6 MB/s eta 0:01:19
#    -- ------------------------------------- 27.8/385.0 MB 4.9 MB/s eta 0:01:14
#    -- ------------------------------------- 28.1/385.0 MB 4.8 MB/s eta 0:01:14
#    -- ------------------------------------- 28.3/385.0 MB 5.0 MB/s eta 0:01:12
#    -- ------------------------------------- 28.5/385.0 MB 5.0 MB/s eta 0:01:11
#    -- ------------------------------------- 28.8/385.0 MB 5.0 MB/s eta 0:01:11
#    --- ------------------------------------ 29.1/385.0 MB 5.0 MB/s eta 0:01:11
#    --- ------------------------------------ 29.3/385.0 MB 5.1 MB/s eta 0:01:11
#    --- ------------------------------------ 29.5/385.0 MB 5.1 MB/s eta 0:01:10
#    --- ------------------------------------ 29.7/385.0 MB 5.0 MB/s eta 0:01:12
#    --- ------------------------------------ 29.9/385.0 MB 5.0 MB/s eta 0:01:12
#    --- ------------------------------------ 30.1/385.0 MB 4.9 MB/s eta 0:01:13
#    --- ------------------------------------ 30.3/385.0 MB 4.9 MB/s eta 0:01:13
#    --- ------------------------------------ 30.5/385.0 MB 4.9 MB/s eta 0:01:14
#    --- ------------------------------------ 30.7/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 30.8/385.0 MB 4.8 MB/s eta 0:01:15
#    --- ------------------------------------ 31.1/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 31.4/385.0 MB 4.8 MB/s eta 0:01:15
#    --- ------------------------------------ 31.6/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 31.8/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 32.2/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 32.5/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 32.7/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 33.0/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 33.4/385.0 MB 4.8 MB/s eta 0:01:14
#    --- ------------------------------------ 33.7/385.0 MB 4.8 MB/s eta 0:01:13
#    --- ------------------------------------ 33.9/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 34.0/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 34.1/385.0 MB 4.6 MB/s eta 0:01:17
#    --- ------------------------------------ 34.3/385.0 MB 4.6 MB/s eta 0:01:17
#    --- ------------------------------------ 34.4/385.0 MB 4.7 MB/s eta 0:01:14
#    --- ------------------------------------ 34.5/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 34.7/385.0 MB 4.7 MB/s eta 0:01:15
#    --- ------------------------------------ 34.9/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 35.1/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 35.2/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 35.5/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 35.6/385.0 MB 4.6 MB/s eta 0:01:16
#    --- ------------------------------------ 35.7/385.0 MB 4.5 MB/s eta 0:01:18
#    --- ------------------------------------ 35.8/385.0 MB 4.5 MB/s eta 0:01:18
#    --- ------------------------------------ 35.9/385.0 MB 4.5 MB/s eta 0:01:18
#    --- ------------------------------------ 36.0/385.0 MB 4.5 MB/s eta 0:01:18
#    --- ------------------------------------ 36.1/385.0 MB 4.4 MB/s eta 0:01:20
#    --- ------------------------------------ 36.2/385.0 MB 4.4 MB/s eta 0:01:20
#    --- ------------------------------------ 36.2/385.0 MB 4.4 MB/s eta 0:01:20
#    --- ------------------------------------ 36.7/385.0 MB 4.3 MB/s eta 0:01:21
#    --- ------------------------------------ 37.1/385.0 MB 4.4 MB/s eta 0:01:20
#    --- ------------------------------------ 37.5/385.0 MB 4.4 MB/s eta 0:01:19
#    --- ------------------------------------ 37.8/385.0 MB 4.4 MB/s eta 0:01:19
#    --- ------------------------------------ 38.1/385.0 MB 4.5 MB/s eta 0:01:18
#    --- ------------------------------------ 38.3/385.0 MB 4.5 MB/s eta 0:01:18
#    ---- ----------------------------------- 38.6/385.0 MB 4.5 MB/s eta 0:01:18
#    ---- ----------------------------------- 38.9/385.0 MB 4.5 MB/s eta 0:01:18
#    ---- ----------------------------------- 39.2/385.0 MB 4.5 MB/s eta 0:01:17
#    ---- ----------------------------------- 39.4/385.0 MB 4.5 MB/s eta 0:01:18
#    ---- ----------------------------------- 39.6/385.0 MB 4.5 MB/s eta 0:01:18
#    ---- ----------------------------------- 39.8/385.0 MB 4.5 MB/s eta 0:01:17
#    ---- ----------------------------------- 40.1/385.0 MB 4.5 MB/s eta 0:01:17
#    ---- ----------------------------------- 40.4/385.0 MB 4.5 MB/s eta 0:01:16
#    ---- ----------------------------------- 40.6/385.0 MB 4.6 MB/s eta 0:01:16
#    ---- ----------------------------------- 40.8/385.0 MB 4.5 MB/s eta 0:01:16
#    ---- ----------------------------------- 41.1/385.0 MB 4.6 MB/s eta 0:01:15
#    ---- ----------------------------------- 41.5/385.0 MB 4.6 MB/s eta 0:01:14
#    ---- ----------------------------------- 41.7/385.0 MB 4.6 MB/s eta 0:01:16
#    ---- ----------------------------------- 42.1/385.0 MB 4.7 MB/s eta 0:01:13
#    ---- ----------------------------------- 42.4/385.0 MB 4.7 MB/s eta 0:01:13
#    ---- ----------------------------------- 42.7/385.0 MB 4.7 MB/s eta 0:01:13
#    ---- ----------------------------------- 42.9/385.0 MB 4.7 MB/s eta 0:01:14
#    ---- ----------------------------------- 43.2/385.0 MB 4.7 MB/s eta 0:01:14
#    ---- ----------------------------------- 43.3/385.0 MB 4.6 MB/s eta 0:01:14
#    ---- ----------------------------------- 43.5/385.0 MB 4.6 MB/s eta 0:01:15
#    ---- ----------------------------------- 43.8/385.0 MB 4.5 MB/s eta 0:01:16
#    ---- ----------------------------------- 44.0/385.0 MB 4.5 MB/s eta 0:01:16
#    ---- ----------------------------------- 44.1/385.0 MB 4.5 MB/s eta 0:01:15
#    ---- ----------------------------------- 44.2/385.0 MB 4.5 MB/s eta 0:01:16
#    ---- ----------------------------------- 44.5/385.0 MB 4.6 MB/s eta 0:01:14
#    ---- ----------------------------------- 44.9/385.0 MB 4.8 MB/s eta 0:01:12
#    ---- ----------------------------------- 45.2/385.0 MB 4.9 MB/s eta 0:01:10
#    ---- ----------------------------------- 45.5/385.0 MB 4.9 MB/s eta 0:01:09
#    ---- ----------------------------------- 45.7/385.0 MB 4.9 MB/s eta 0:01:10
#    ---- ----------------------------------- 46.0/385.0 MB 5.2 MB/s eta 0:01:06
#    ---- ----------------------------------- 46.3/385.0 MB 5.2 MB/s eta 0:01:05
#    ---- ----------------------------------- 46.6/385.0 MB 5.7 MB/s eta 0:00:59
#    ---- ----------------------------------- 46.8/385.0 MB 5.6 MB/s eta 0:01:01
#    ---- ----------------------------------- 46.9/385.0 MB 5.5 MB/s eta 0:01:02
#    ---- ----------------------------------- 47.1/385.0 MB 5.3 MB/s eta 0:01:04
#    ---- ----------------------------------- 47.1/385.0 MB 5.2 MB/s eta 0:01:05
#    ---- ----------------------------------- 47.2/385.0 MB 5.1 MB/s eta 0:01:07
#    ---- ----------------------------------- 47.3/385.0 MB 5.0 MB/s eta 0:01:08
#    ---- ----------------------------------- 47.6/385.0 MB 5.0 MB/s eta 0:01:07
#    ---- ----------------------------------- 47.9/385.0 MB 5.0 MB/s eta 0:01:07
#    ---- ----------------------------------- 48.1/385.0 MB 5.0 MB/s eta 0:01:08
#    ----- ---------------------------------- 48.3/385.0 MB 5.0 MB/s eta 0:01:08
#    ----- ---------------------------------- 48.4/385.0 MB 4.9 MB/s eta 0:01:09
#    ----- ---------------------------------- 48.7/385.0 MB 4.9 MB/s eta 0:01:09
#    ----- ---------------------------------- 48.9/385.0 MB 4.9 MB/s eta 0:01:10
#    ----- ---------------------------------- 49.1/385.0 MB 4.8 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.3/385.0 MB 4.7 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.5/385.0 MB 4.7 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.7/385.0 MB 4.8 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.7/385.0 MB 4.7 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.8/385.0 MB 4.6 MB/s eta 0:01:13
#    ----- ---------------------------------- 50.1/385.0 MB 4.6 MB/s eta 0:01:13
#    ----- ---------------------------------- 50.1/385.0 MB 4.6 MB/s eta 0:01:13
#    ----- ---------------------------------- 50.3/385.0 MB 4.6 MB/s eta 0:01:14
#    ----- ---------------------------------- 50.3/385.0 MB 4.5 MB/s eta 0:01:14
#    ----- ---------------------------------- 50.4/385.0 MB 4.4 MB/s eta 0:01:16
#    ----- ---------------------------------- 50.6/385.0 MB 4.4 MB/s eta 0:01:17
#    ----- ---------------------------------- 50.7/385.0 MB 4.4 MB/s eta 0:01:17
#    ----- ---------------------------------- 50.8/385.0 MB 4.3 MB/s eta 0:01:19
#    ----- ---------------------------------- 50.8/385.0 MB 4.3 MB/s eta 0:01:19
#    ----- ---------------------------------- 50.8/385.0 MB 4.3 MB/s eta 0:01:19
#    ----- ---------------------------------- 50.8/385.0 MB 4.3 MB/s eta 0:01:19
#    ----- ---------------------------------- 51.5/385.0 MB 4.2 MB/s eta 0:01:19
#    ----- ---------------------------------- 51.8/385.0 MB 4.2 MB/s eta 0:01:19
#    ----- ---------------------------------- 52.0/385.0 MB 4.2 MB/s eta 0:01:20
#    ----- ---------------------------------- 52.3/385.0 MB 4.2 MB/s eta 0:01:20
#    ----- ---------------------------------- 52.5/385.0 MB 4.1 MB/s eta 0:01:21
#    ----- ---------------------------------- 52.7/385.0 MB 4.1 MB/s eta 0:01:21
#    ----- ---------------------------------- 53.0/385.0 MB 4.1 MB/s eta 0:01:21
#    ----- ---------------------------------- 53.1/385.0 MB 4.1 MB/s eta 0:01:22
#    ----- ---------------------------------- 53.3/385.0 MB 4.1 MB/s eta 0:01:22
#    ----- ---------------------------------- 53.5/385.0 MB 4.0 MB/s eta 0:01:23
#    ----- ---------------------------------- 53.6/385.0 MB 4.0 MB/s eta 0:01:23
#    ----- ---------------------------------- 53.7/385.0 MB 4.0 MB/s eta 0:01:24
#    ----- ---------------------------------- 53.7/385.0 MB 4.0 MB/s eta 0:01:24
#    ----- ---------------------------------- 53.8/385.0 MB 3.9 MB/s eta 0:01:25
#    ----- ---------------------------------- 53.8/385.0 MB 3.9 MB/s eta 0:01:26
#    ----- ---------------------------------- 53.9/385.0 MB 3.8 MB/s eta 0:01:28
#    ----- ---------------------------------- 54.0/385.0 MB 3.8 MB/s eta 0:01:27
#    ----- ---------------------------------- 54.0/385.0 MB 3.8 MB/s eta 0:01:27
#    ----- ---------------------------------- 54.5/385.0 MB 3.8 MB/s eta 0:01:27
#    ----- ---------------------------------- 54.7/385.0 MB 3.8 MB/s eta 0:01:27
#    ----- ---------------------------------- 54.8/385.0 MB 3.8 MB/s eta 0:01:28
#    ----- ---------------------------------- 55.1/385.0 MB 3.7 MB/s eta 0:01:29
#    ----- ---------------------------------- 55.4/385.0 MB 3.7 MB/s eta 0:01:29
#    ----- ---------------------------------- 55.5/385.0 MB 3.7 MB/s eta 0:01:29
#    ----- ---------------------------------- 55.7/385.0 MB 3.7 MB/s eta 0:01:30
#    ----- ---------------------------------- 55.9/385.0 MB 3.7 MB/s eta 0:01:30
#    ----- ---------------------------------- 56.0/385.0 MB 3.7 MB/s eta 0:01:30
#    ----- ---------------------------------- 56.2/385.0 MB 3.7 MB/s eta 0:01:30
#    ----- ---------------------------------- 56.3/385.0 MB 3.6 MB/s eta 0:01:31
#    ----- ---------------------------------- 56.6/385.0 MB 3.6 MB/s eta 0:01:31
#    ----- ---------------------------------- 56.9/385.0 MB 3.6 MB/s eta 0:01:31
#    ----- ---------------------------------- 57.1/385.0 MB 3.6 MB/s eta 0:01:32
#    ----- ---------------------------------- 57.2/385.0 MB 3.6 MB/s eta 0:01:31
#    ----- ---------------------------------- 57.5/385.0 MB 3.8 MB/s eta 0:01:28
#    ----- ---------------------------------- 57.6/385.0 MB 3.7 MB/s eta 0:01:28
#    ------ --------------------------------- 57.8/385.0 MB 3.7 MB/s eta 0:01:28
#    ------ --------------------------------- 58.0/385.0 MB 3.7 MB/s eta 0:01:28
#    ------ --------------------------------- 58.2/385.0 MB 3.7 MB/s eta 0:01:28
#    ------ --------------------------------- 58.3/385.0 MB 3.7 MB/s eta 0:01:29
#    ------ --------------------------------- 58.3/385.0 MB 3.6 MB/s eta 0:01:31
#    ------ --------------------------------- 58.5/385.0 MB 3.6 MB/s eta 0:01:32
#    ------ --------------------------------- 58.5/385.0 MB 3.6 MB/s eta 0:01:32
#    ------ --------------------------------- 58.6/385.0 MB 3.5 MB/s eta 0:01:33
#    ------ --------------------------------- 58.7/385.0 MB 3.5 MB/s eta 0:01:33
#    ------ --------------------------------- 58.8/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 59.0/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 59.1/385.0 MB 3.4 MB/s eta 0:01:35
#    ------ --------------------------------- 59.4/385.0 MB 3.5 MB/s eta 0:01:33
#    ------ --------------------------------- 59.5/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 59.6/385.0 MB 3.4 MB/s eta 0:01:35
#    ------ --------------------------------- 59.9/385.0 MB 3.4 MB/s eta 0:01:36
#    ------ --------------------------------- 60.1/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 60.3/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 60.5/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 60.7/385.0 MB 3.6 MB/s eta 0:01:30
#    ------ --------------------------------- 61.0/385.0 MB 3.7 MB/s eta 0:01:29
#    ------ --------------------------------- 61.2/385.0 MB 3.8 MB/s eta 0:01:26
#    ------ --------------------------------- 61.3/385.0 MB 3.7 MB/s eta 0:01:27
#    ------ --------------------------------- 61.6/385.0 MB 3.7 MB/s eta 0:01:28
#    ------ --------------------------------- 61.6/385.0 MB 3.7 MB/s eta 0:01:29
#    ------ --------------------------------- 61.8/385.0 MB 3.6 MB/s eta 0:01:29
#    ------ --------------------------------- 61.9/385.0 MB 3.6 MB/s eta 0:01:30
#    ------ --------------------------------- 61.9/385.0 MB 3.6 MB/s eta 0:01:31
#    ------ --------------------------------- 62.1/385.0 MB 3.5 MB/s eta 0:01:32
#    ------ --------------------------------- 62.2/385.0 MB 3.5 MB/s eta 0:01:33
#    ------ --------------------------------- 62.2/385.0 MB 3.5 MB/s eta 0:01:33
#    ------ --------------------------------- 62.3/385.0 MB 3.5 MB/s eta 0:01:34
#    ------ --------------------------------- 62.3/385.0 MB 3.4 MB/s eta 0:01:36
#    ------ --------------------------------- 62.4/385.0 MB 3.4 MB/s eta 0:01:37
#    ------ --------------------------------- 62.4/385.0 MB 3.3 MB/s eta 0:01:37
#    ------ --------------------------------- 62.4/385.0 MB 3.3 MB/s eta 0:01:38
#    ------ --------------------------------- 62.5/385.0 MB 3.3 MB/s eta 0:01:39
#    ------ --------------------------------- 62.5/385.0 MB 3.3 MB/s eta 0:01:39
#    ------ --------------------------------- 62.5/385.0 MB 3.3 MB/s eta 0:01:39
#    ------ --------------------------------- 62.9/385.0 MB 3.2 MB/s eta 0:01:41
#    ------ --------------------------------- 63.0/385.0 MB 3.2 MB/s eta 0:01:42
#    ------ --------------------------------- 63.1/385.0 MB 3.2 MB/s eta 0:01:42
#    ------ --------------------------------- 63.3/385.0 MB 3.1 MB/s eta 0:01:43
#    ------ --------------------------------- 63.5/385.0 MB 3.2 MB/s eta 0:01:42
#    ------ --------------------------------- 63.7/385.0 MB 3.2 MB/s eta 0:01:42
#    ------ --------------------------------- 63.8/385.0 MB 3.2 MB/s eta 0:01:42
#    ------ --------------------------------- 64.1/385.0 MB 3.3 MB/s eta 0:01:37
#    ------ --------------------------------- 64.2/385.0 MB 3.3 MB/s eta 0:01:38
#    ------ --------------------------------- 64.3/385.0 MB 3.3 MB/s eta 0:01:37
#    ------ --------------------------------- 64.4/385.0 MB 3.3 MB/s eta 0:01:37
#    ------ --------------------------------- 64.6/385.0 MB 3.3 MB/s eta 0:01:38
#    ------ --------------------------------- 64.8/385.0 MB 3.3 MB/s eta 0:01:38
#    ------ --------------------------------- 65.0/385.0 MB 3.2 MB/s eta 0:01:39
#    ------ --------------------------------- 65.1/385.0 MB 3.2 MB/s eta 0:01:39
#    ------ --------------------------------- 65.3/385.0 MB 3.2 MB/s eta 0:01:39
#    ------ --------------------------------- 65.5/385.0 MB 3.2 MB/s eta 0:01:40
#    ------ --------------------------------- 65.7/385.0 MB 3.2 MB/s eta 0:01:40
#    ------ --------------------------------- 65.8/385.0 MB 3.2 MB/s eta 0:01:40
#    ------ --------------------------------- 66.0/385.0 MB 3.2 MB/s eta 0:01:41
#    ------ --------------------------------- 66.2/385.0 MB 3.2 MB/s eta 0:01:40
#    ------ --------------------------------- 66.4/385.0 MB 3.2 MB/s eta 0:01:41
#    ------ --------------------------------- 66.7/385.0 MB 3.2 MB/s eta 0:01:40
#    ------ --------------------------------- 66.8/385.0 MB 3.2 MB/s eta 0:01:41
#    ------ --------------------------------- 66.9/385.0 MB 3.2 MB/s eta 0:01:41
#    ------ --------------------------------- 67.0/385.0 MB 3.1 MB/s eta 0:01:42
#    ------ --------------------------------- 67.1/385.0 MB 3.1 MB/s eta 0:01:43
#    ------ --------------------------------- 67.2/385.0 MB 3.1 MB/s eta 0:01:43
#    ------ --------------------------------- 67.3/385.0 MB 3.0 MB/s eta 0:01:45
#    ------ --------------------------------- 67.4/385.0 MB 3.0 MB/s eta 0:01:45
#    ------- -------------------------------- 67.4/385.0 MB 3.0 MB/s eta 0:01:46
#    ------- -------------------------------- 67.6/385.0 MB 3.0 MB/s eta 0:01:46
#    ------- -------------------------------- 67.9/385.0 MB 3.0 MB/s eta 0:01:45
#    ------- -------------------------------- 68.0/385.0 MB 3.0 MB/s eta 0:01:46
#    ------- -------------------------------- 68.1/385.0 MB 3.0 MB/s eta 0:01:46
#    ------- -------------------------------- 68.2/385.0 MB 3.0 MB/s eta 0:01:47
#    ------- -------------------------------- 68.3/385.0 MB 2.9 MB/s eta 0:01:48
#    ------- -------------------------------- 68.3/385.0 MB 2.9 MB/s eta 0:01:49
#    ------- -------------------------------- 68.4/385.0 MB 2.9 MB/s eta 0:01:51
#    ------- -------------------------------- 68.4/385.0 MB 2.9 MB/s eta 0:01:51
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
#    ------- -------------------------------- 68.5/385.0 MB 2.8 MB/s eta 0:01:52
# ...
#    ------------------------------------- -- 362.0/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 362.1/385.0 MB 4.9 MB/s eta 0:00:05
#    ------------------------------------- -- 362.3/385.0 MB 4.8 MB/s eta 0:00:05
#    ------------------------------------- -- 362.3/385.0 MB 4.7 MB/s eta 0:00:05
#    ------------------------------------- -- 362.6/385.0 MB 4.9 MB/s eta 0:00:05
#    ------------------------------------- -- 362.8/385.0 MB 4.9 MB/s eta 0:00:05
#    ------------------------------------- -- 363.1/385.0 MB 4.9 MB/s eta 0:00:05
#    ------------------------------------- -- 363.5/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 363.7/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 364.1/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 364.3/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 364.4/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 364.7/385.0 MB 5.0 MB/s eta 0:00:05
#    ------------------------------------- -- 364.8/385.0 MB 4.8 MB/s eta 0:00:05
#    ------------------------------------- -- 364.9/385.0 MB 4.8 MB/s eta 0:00:05
#    ------------------------------------- -- 365.3/385.0 MB 4.8 MB/s eta 0:00:05
#    ------------------------------------- -- 365.4/385.0 MB 4.8 MB/s eta 0:00:05
#    ------------------------------------- -- 365.4/385.0 MB 4.7 MB/s eta 0:00:05
#    ------------------------------------- -- 365.5/385.0 MB 4.6 MB/s eta 0:00:05
#    ------------------------------------- -- 365.8/385.0 MB 4.7 MB/s eta 0:00:05
#    -------------------------------------- - 366.0/385.0 MB 4.7 MB/s eta 0:00:05
#    -------------------------------------- - 366.3/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 366.6/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 367.0/385.0 MB 4.8 MB/s eta 0:00:04
#    -------------------------------------- - 367.2/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 367.6/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 367.8/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 368.1/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 368.4/385.0 MB 4.8 MB/s eta 0:00:04
#    -------------------------------------- - 368.7/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 368.9/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 369.1/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 369.3/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 369.5/385.0 MB 4.6 MB/s eta 0:00:04
#    -------------------------------------- - 369.6/385.0 MB 4.7 MB/s eta 0:00:04
#    -------------------------------------- - 369.9/385.0 MB 4.6 MB/s eta 0:00:04
#    -------------------------------------- - 370.1/385.0 MB 4.6 MB/s eta 0:00:04
#    -------------------------------------- - 370.4/385.0 MB 4.6 MB/s eta 0:00:04
#    -------------------------------------- - 370.6/385.0 MB 4.5 MB/s eta 0:00:04
#    -------------------------------------- - 370.8/385.0 MB 4.5 MB/s eta 0:00:04
#    -------------------------------------- - 371.2/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 371.3/385.0 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 371.5/385.0 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 371.9/385.0 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 372.1/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 372.3/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 372.4/385.0 MB 4.8 MB/s eta 0:00:03
#    -------------------------------------- - 372.6/385.0 MB 4.8 MB/s eta 0:00:03
#    -------------------------------------- - 372.9/385.0 MB 4.9 MB/s eta 0:00:03
#    -------------------------------------- - 373.1/385.0 MB 4.8 MB/s eta 0:00:03
#    -------------------------------------- - 373.3/385.0 MB 4.8 MB/s eta 0:00:03
#    -------------------------------------- - 373.5/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 373.8/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 374.1/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 374.3/385.0 MB 4.8 MB/s eta 0:00:03
#    -------------------------------------- - 374.3/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 374.4/385.0 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 374.6/385.0 MB 4.6 MB/s eta 0:00:03
#    -------------------------------------- - 375.0/385.0 MB 4.7 MB/s eta 0:00:03
#    -------------------------------------- - 375.1/385.0 MB 4.8 MB/s eta 0:00:03
#    ---------------------------------------  375.5/385.0 MB 4.8 MB/s eta 0:00:02
#    ---------------------------------------  375.9/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  376.1/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  376.3/385.0 MB 5.1 MB/s eta 0:00:02
#    ---------------------------------------  376.6/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  377.0/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  377.3/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  377.5/385.0 MB 5.1 MB/s eta 0:00:02
#    ---------------------------------------  377.7/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  377.8/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  378.1/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  378.3/385.0 MB 4.9 MB/s eta 0:00:02
#    ---------------------------------------  378.5/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  378.7/385.0 MB 4.9 MB/s eta 0:00:02
#    ---------------------------------------  379.1/385.0 MB 4.9 MB/s eta 0:00:02
#    ---------------------------------------  379.4/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  379.5/385.0 MB 4.9 MB/s eta 0:00:02
#    ---------------------------------------  379.7/385.0 MB 5.0 MB/s eta 0:00:02
#    ---------------------------------------  380.2/385.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  380.4/385.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  380.8/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  381.0/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  381.2/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  381.4/385.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  381.7/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  382.0/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  382.3/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  382.5/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  382.9/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  383.0/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  383.2/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  383.3/385.0 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  383.7/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  383.9/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  384.1/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  384.4/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  384.6/385.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  384.8/385.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  384.9/385.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  385.0/385.0 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 385.0/385.0 MB 3.6 MB/s eta 0:00:00
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.64.1-cp311-cp311-win_amd64.whl (4.1 MB)
# Using cached h5py-3.11.0-cp311-cp311-win_amd64.whl (3.0 MB)
# Using cached keras-3.4.1-py3-none-any.whl (1.1 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Downloading tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.5 MB 12.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.4/5.5 MB 6.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/5.5 MB 5.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/5.5 MB 6.0 MB/s eta 0:00:01
#    ------- -------------------------------- 1.1/5.5 MB 5.7 MB/s eta 0:00:01
#    --------- ------------------------------ 1.2/5.5 MB 5.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.5 MB 5.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.6/5.5 MB 4.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.7/5.5 MB 4.8 MB/s eta 0:00:01
#    -------------- ------------------------- 2.0/5.5 MB 4.9 MB/s eta 0:00:01
#    --------------- ------------------------ 2.2/5.5 MB 4.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.5 MB 4.7 MB/s eta 0:00:01
#    ------------------- -------------------- 2.6/5.5 MB 4.8 MB/s eta 0:00:01
#    -------------------- ------------------- 2.9/5.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 3.3/5.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------- -------------- 3.5/5.5 MB 4.7 MB/s eta 0:00:01
#    --------------------------- ------------ 3.8/5.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.0/5.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.1/5.5 MB 4.7 MB/s eta 0:00:01
#    ------------------------------- -------- 4.3/5.5 MB 4.7 MB/s eta 0:00:01
#    --------------------------------- ------ 4.6/5.5 MB 4.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.9/5.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 4.8 MB/s eta 0:00:00
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
# Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl (37 kB)
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ---------------------------------------- 163.0/163.0 kB 9.5 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB 2.9 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB ? eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.4 kB ? eta -:--:--
#    -------------------------------------- - 102.4/105.4 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 105.4/105.4 kB 2.0 MB/s eta 0:00:00
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.4 kB ? eta -:--:--
#    ---------------------------------------- 121.4/121.4 kB 3.6 MB/s eta 0:00:00
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    ---------------------------- ----------- 163.8/227.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 227.3/227.3 kB 2.8 MB/s eta 0:00:00
# Using cached wheel-0.43.0-py3-none-any.whl (65 kB)
# Using cached namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp311-cp311-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.5 kB ? eta -:--:--
#    ---------------------------- ----------- 194.6/268.5 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 268.5/268.5 kB 3.3 MB/s eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    --------------- ------------------------ 92.2/240.7 kB 5.1 MB/s eta 0:00:01
#    ------------------------------ --------- 184.3/240.7 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 240.7/240.7 kB 2.1 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, wrapt, wheel, werkzeug, urllib3, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, mdurl, markdown, idna, h5py, grpcio, google-pasta, gast, charset-normalizer, certifi, tensorboard, requests, markdown-it-py, astunparse, rich, keras, tensorflow-intel, tensorflow
# Successfully installed astunparse-1.6.3 certifi-2024.7.4 charset-normalizer-3.3.2 gast-0.6.0 google-pasta-0.2.0 grpcio-1.64.1 h5py-3.11.0 idna-3.7 keras-3.4.1 libclang-18.1.1 markdown-3.6 markdown-it-py-3.0.0 mdurl-0.1.2 namex-0.0.8 optree-0.12.1 requests-2.32.3 rich-13.7.1 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-intel-2.17.0 tensorflow-io-gcs-filesystem-0.31.0 urllib3-2.2.2 werkzeug-3.0.3 wheel-0.43.0 wrapt-1.16.0
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\debas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from tensorflow import keras
from keras.models import Model
from keras.layers import Dense

# %%
import collections

import os
import numpy as np

from tensorflow.keras import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GRU, Dense, TimeDistributed, Activation, RepeatVector, Bidirectional, LSTM
from keras.layers.embeddings import Embedding
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import sparse_categorical_crossentropy

# %%
def load_data(path):
    input_file = os.path.join(path)
    with open(input_file, "r") as f:
        data = f.read()

    return data.split('\n')

# %%
# Load English data
english_sentences = load_data('small_vocab_en')
# Load French data
french_sentences = load_data('small_vocab_fr')

# %%
for sample_i in range(1):
    print('small_vocab_en Line {}:  {}'.format(sample_i + 1, english_sentences[sample_i]))
    print('small_vocab_fr Line {}:  {}'.format(sample_i + 1, french_sentences[sample_i]))
# Out:
# small_vocab_en Line 1:  new jersey is sometimes quiet during autumn , and it is snowy in april .
# small_vocab_fr Line 1:  new jersey est parfois calme pendant l' automne , et il est neigeux en avril .

# %%
english_words_counter = collections.Counter([word for sentence in english_sentences for word in sentence.split()])
french_words_counter = collections.Counter([word for sentence in french_sentences for word in sentence.split()])

print('{} total English words.'.format(len([word for sentence in english_sentences for word in sentence.split()])))
print('{} unique English words.'.format(len(english_words_counter)))
print()
print('{} total French words.'.format(len([word for sentence in french_sentences for word in sentence.split()])))
print('{} unique French words.'.format(len(french_words_counter)))
# Out:
# 1823250 total English words.
# 227 unique English words.
#
# 1961295 total French words.
# 355 unique French words.

# %%
def tokenize(x):
    tokenizer = Tokenizer(split=' ', char_level=False)
    tokenizer.fit_on_texts(x)
    return tokenizer.texts_to_sequences(x), tokenizer

# %%
def pad(x, length=None):
    if length is None:
        length = max([len(sentence) for sentence in x])
    
    return pad_sequences(x, maxlen=length, padding='post', truncating='post')

# %%
def preprocess(x, y):
    preprocess_x, x_tk = tokenize(x)
    preprocess_y, y_tk = tokenize(y)

    preprocess_x = pad(preprocess_x)
    preprocess_y = pad(preprocess_y)

    # Keras's sparse_categorical_crossentropy function requires the labels to be in 3 dimensions
    preprocess_y = preprocess_y.reshape(*preprocess_y.shape, 1) 

    return preprocess_x, preprocess_y, x_tk, y_tk

# %%
preproc_english_sentences, preproc_french_sentences, english_tokenizer, french_tokenizer = preprocess(english_sentences, french_sentences)

max_english_sequence_length = preproc_english_sentences.shape[1]
max_french_sequence_length = preproc_french_sentences.shape[1]
english_vocab_size = len(english_tokenizer.word_index)
french_vocab_size = len(french_tokenizer.word_index)

print("Max English sentence length:", max_english_sequence_length)
print("Max French sentence length:", max_french_sequence_length)
print("English vocabulary size:", english_vocab_size)
print("French vocabulary size:", french_vocab_size)
# Out:
# Max English sentence length: 15
# Max French sentence length: 21
# English vocabulary size: 199
# French vocabulary size: 344

# %%
print(preproc_english_sentences.shape)
# Out:
# (137861, 15)

# %%
def logits_to_text(logits, tokenizer):
    index_to_words = {ids: word for word, ids in tokenizer.word_index.items()}
    index_to_words[0] = '<PAD>'

    decoded_sentence = []
    for prediction in np.argmax(logits, 1):
      if index_to_words[prediction]!='<PAD>':
        decoded_sentence.append(index_to_words[prediction])

    return ' '.join(decoded_sentence)

# %% [markdown]
# ## Model 1

# %%
def token_to_words(sequence, tokenizer):
    index_to_words = {ids: word for word, ids in tokenizer.word_index.items()}
    index_to_words[0] = '<PAD>'

    decoded_sentence = []
    for token in sequence:
      if index_to_words[token]!='<PAD>':
        decoded_sentence.append(index_to_words[token])

    return decoded_sentence

# %%
def simple_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    learning_rate = 0.001

    model = Sequential()
    
    model.add(LSTM(64, return_sequences=True, activation="tanh"))
    model.add(TimeDistributed(Dense(french_vocab_size, activation="softmax")))
    
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    
    model.build((None,21,1)) # ????
    
    return model

# %%
# Reshaping the input to work with a basic RNN
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
tmp_x = tmp_x.reshape(tmp_x.shape[0],tmp_x.shape[1],1) # reshape as 3D (batchsize, timesteps, 1) for LSTM input

# Train the neural network
simple_rnn_model = simple_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

simple_rnn_model.summary()

simple_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=20, validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 21, 64)            16896
#
#  time_distributed (TimeDistr  (None, 21, 344)          22360
#  ibuted)
#
# =================================================================
# Total params: 39,256
# Trainable params: 39,256
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 108/108 [==============================] - 5s 19ms/step - loss: 3.3688 - accuracy: 0.4206 - val_loss: nan - val_accuracy: 0.4690
# Epoch 2/20
# 108/108 [==============================] - 2s 14ms/step - loss: 2.4047 - accuracy: 0.4771 - val_loss: nan - val_accuracy: 0.4882
# Epoch 3/20
# 108/108 [==============================] - 2s 14ms/step - loss: 2.1581 - accuracy: 0.5043 - val_loss: nan - val_accuracy: 0.5294
# Epoch 4/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.9411 - accuracy: 0.5509 - val_loss: nan - val_accuracy: 0.5670
# Epoch 5/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.7884 - accuracy: 0.5728 - val_loss: nan - val_accuracy: 0.5816
# Epoch 6/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.6966 - accuracy: 0.5837 - val_loss: nan - val_accuracy: 0.5907
# Epoch 7/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.6330 - accuracy: 0.5924 - val_loss: nan - val_accuracy: 0.5963
# Epoch 8/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.5810 - accuracy: 0.5980 - val_loss: nan - val_accuracy: 0.5998
# Epoch 9/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.5354 - accuracy: 0.6022 - val_loss: nan - val_accuracy: 0.6035
# Epoch 10/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.4951 - accuracy: 0.6091 - val_loss: nan - val_accuracy: 0.6104
# Epoch 11/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.4605 - accuracy: 0.6201 - val_loss: nan - val_accuracy: 0.6244
# Epoch 12/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.4290 - accuracy: 0.6264 - val_loss: nan - val_accuracy: 0.6278
# Epoch 13/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.4007 - accuracy: 0.6299 - val_loss: nan - val_accuracy: 0.6327
# Epoch 14/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.3736 - accuracy: 0.6344 - val_loss: nan - val_accuracy: 0.6357
# Epoch 15/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.3494 - accuracy: 0.6382 - val_loss: nan - val_accuracy: 0.6407
# Epoch 16/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.3278 - accuracy: 0.6412 - val_loss: nan - val_accuracy: 0.6434
# Epoch 17/20
# 108/108 [==============================] - 2s 16ms/step - loss: 1.3080 - accuracy: 0.6439 - val_loss: nan - val_accuracy: 0.6445
# Epoch 18/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.2909 - accuracy: 0.6451 - val_loss: nan - val_accuracy: 0.6463
# Epoch 19/20
# 108/108 [==============================] - 2s 15ms/step - loss: 1.2751 - accuracy: 0.6470 - val_loss: nan - val_accuracy: 0.6481
# Epoch 20/20
# 108/108 [==============================] - 2s 14ms/step - loss: 1.2612 - accuracy: 0.6485 - val_loss: nan - val_accuracy: 0.6498

# %%
def translate(prediction, french_sentence):
    translation = logits_to_text(prediction[0], french_tokenizer)
    standard = ' '.join(token_to_words(french_sentence[0][:,0],french_tokenizer)) 
    print('---- French Sentence ----')
    print(standard)
    print()
    print('---- Prediction ----')
    print(translation)
    print()

# %%
print('---- English Sentence ----')
print(' '.join(token_to_words(tmp_x[:1][0][:,0],english_tokenizer)))
print()
translate(simple_rnn_model.predict(tmp_x[:1]), preproc_french_sentences[:1])
# Out:
# ---- English Sentence ----
# new jersey is sometimes quiet during autumn and it is snowy in april
#
# ---- French Sentence ----
# new jersey est parfois calme pendant l' automne et il est neigeux en avril
#
# ---- Prediction ----
# new jersey est parfois chaud en l' et il est est en en

# %% [markdown]
# ## Model 2

# %%
def embed_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    learning_rate = 0.001
    embedding_size = 256 # dimensions of word vectors
    
    model = Sequential()
    
    model.add(Embedding(input_dim = english_vocab_size, output_dim = embedding_size, 
                           input_length = output_sequence_length))
    
    model.add(LSTM(64, return_sequences=True, activation="tanh"))
    
    model.add(TimeDistributed(Dense(french_vocab_size, activation="softmax")))
    
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    
    return model

# %%
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)
# tmp_x = tmp_x.reshape((-1, preproc_french_sentences.shape[-2]))    # reshaped to (batchsize, seq_length) for Embedding input

# Train the neural network
embed_rnn_model = embed_model(
    tmp_x.shape,
    max_french_sequence_length,
    english_vocab_size,
    french_vocab_size)

embed_rnn_model.summary()
    
embed_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=20, validation_split=0.2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 21, 256)           50944
#
#  lstm_1 (LSTM)               (None, 21, 64)            82176
#
#  time_distributed_1 (TimeDis  (None, 21, 344)          22360
#  tributed)
#
# =================================================================
# Total params: 155,480
# Trainable params: 155,480
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 108/108 [==============================] - 4s 21ms/step - loss: 3.5627 - accuracy: 0.4053 - val_loss: nan - val_accuracy: 0.4425
# Epoch 2/20
# 108/108 [==============================] - 2s 17ms/step - loss: 2.4110 - accuracy: 0.4902 - val_loss: nan - val_accuracy: 0.5354
# Epoch 3/20
# 108/108 [==============================] - 2s 17ms/step - loss: 1.7719 - accuracy: 0.5832 - val_loss: nan - val_accuracy: 0.6267
# Epoch 4/20
# 108/108 [==============================] - 2s 17ms/step - loss: 1.3571 - accuracy: 0.6644 - val_loss: nan - val_accuracy: 0.7050
# Epoch 5/20
# 108/108 [==============================] - 2s 17ms/step - loss: 1.0457 - accuracy: 0.7346 - val_loss: nan - val_accuracy: 0.7615
# Epoch 6/20
# 108/108 [==============================] - 2s 18ms/step - loss: 0.8535 - accuracy: 0.7748 - val_loss: nan - val_accuracy: 0.7879
# Epoch 7/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.7427 - accuracy: 0.7952 - val_loss: nan - val_accuracy: 0.8049
# Epoch 8/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.6699 - accuracy: 0.8095 - val_loss: nan - val_accuracy: 0.8167
# Epoch 9/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.6159 - accuracy: 0.8217 - val_loss: nan - val_accuracy: 0.8293
# Epoch 10/20
# 108/108 [==============================] - 2s 18ms/step - loss: 0.5717 - accuracy: 0.8334 - val_loss: nan - val_accuracy: 0.8389
# Epoch 11/20
# 108/108 [==============================] - 2s 18ms/step - loss: 0.5333 - accuracy: 0.8437 - val_loss: nan - val_accuracy: 0.8487
# Epoch 12/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.5018 - accuracy: 0.8523 - val_loss: nan - val_accuracy: 0.8554
# Epoch 13/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.4745 - accuracy: 0.8596 - val_loss: nan - val_accuracy: 0.8598
# Epoch 14/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.4510 - accuracy: 0.8664 - val_loss: nan - val_accuracy: 0.8697
# Epoch 15/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.4313 - accuracy: 0.8718 - val_loss: nan - val_accuracy: 0.8736
# Epoch 16/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.4145 - accuracy: 0.8763 - val_loss: nan - val_accuracy: 0.8796
# Epoch 17/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.3974 - accuracy: 0.8818 - val_loss: nan - val_accuracy: 0.8835
# Epoch 18/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.3847 - accuracy: 0.8853 - val_loss: nan - val_accuracy: 0.8868
# Epoch 19/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.3720 - accuracy: 0.8888 - val_loss: nan - val_accuracy: 0.8884
# Epoch 20/20
# 108/108 [==============================] - 2s 17ms/step - loss: 0.3627 - accuracy: 0.8910 - val_loss: nan - val_accuracy: 0.8923

# %%
print('---- English Sentence ----')
print(' '.join(token_to_words(tmp_x[:1][0],english_tokenizer) ))
print()
translate(embed_rnn_model.predict(tmp_x[:1]), preproc_french_sentences[:1])
# Out:
# ---- English Sentence ----
# new jersey is sometimes quiet during autumn and it is snowy in april
#
# ---- French Sentence ----
# new jersey est parfois calme pendant l' automne et il est neigeux en avril
#
# ---- Prediction ----
# new jersey est parfois calme en l' automne et il est neigeux en avril

# %% [markdown]
# ## Model 3

# %%
def emb_bd_model(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    learning_rate = 0.001
    embedding_size = 256

    model = Sequential()
    
    model.add(Embedding(input_dim = english_vocab_size, output_dim = embedding_size, 
                           input_length = output_sequence_length))
    
    model.add(Bidirectional(LSTM(64, return_sequences=True, activation="tanh")))
    
    model.add(TimeDistributed(Dense(french_vocab_size, activation="softmax")))
    
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
   
    return model

# %%
tmp_x = pad(preproc_english_sentences, max_french_sequence_length)

# Train the neural network
emb_bd_rnn_model = emb_bd_model(
                        tmp_x.shape,
                        max_french_sequence_length,
                        english_vocab_size,
                        french_vocab_size)

emb_bd_rnn_model.summary()

emb_bd_rnn_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=20, validation_split=0.2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 21, 256)           50944
#
#  bidirectional (Bidirectiona  (None, 21, 128)          164352
#  l)
#
#  time_distributed_2 (TimeDis  (None, 21, 344)          44376
#  tributed)
#
# =================================================================
# Total params: 259,672
# Trainable params: 259,672
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 108/108 [==============================] - 6s 31ms/step - loss: 3.1397 - accuracy: 0.4511 - val_loss: nan - val_accuracy: 0.5014
# Epoch 2/20
# 108/108 [==============================] - 3s 24ms/step - loss: 1.9493 - accuracy: 0.5434 - val_loss: nan - val_accuracy: 0.6000
# Epoch 3/20
# 108/108 [==============================] - 3s 24ms/step - loss: 1.3385 - accuracy: 0.6592 - val_loss: nan - val_accuracy: 0.7174
# Epoch 4/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.9399 - accuracy: 0.7480 - val_loss: nan - val_accuracy: 0.7745
# Epoch 5/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.7360 - accuracy: 0.7912 - val_loss: nan - val_accuracy: 0.8071
# Epoch 6/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.6201 - accuracy: 0.8182 - val_loss: nan - val_accuracy: 0.8270
# Epoch 7/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.5404 - accuracy: 0.8397 - val_loss: nan - val_accuracy: 0.8503
# Epoch 8/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.4823 - accuracy: 0.8570 - val_loss: nan - val_accuracy: 0.8652
# Epoch 9/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.4381 - accuracy: 0.8697 - val_loss: nan - val_accuracy: 0.8740
# Epoch 10/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.4031 - accuracy: 0.8800 - val_loss: nan - val_accuracy: 0.8865
# Epoch 11/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.3736 - accuracy: 0.8887 - val_loss: nan - val_accuracy: 0.8933
# Epoch 12/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.3498 - accuracy: 0.8960 - val_loss: nan - val_accuracy: 0.9003
# Epoch 13/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.3272 - accuracy: 0.9029 - val_loss: nan - val_accuracy: 0.9061
# Epoch 14/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.3093 - accuracy: 0.9081 - val_loss: nan - val_accuracy: 0.9044
# Epoch 15/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2930 - accuracy: 0.9132 - val_loss: nan - val_accuracy: 0.9144
# Epoch 16/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2777 - accuracy: 0.9181 - val_loss: nan - val_accuracy: 0.9193
# Epoch 17/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2670 - accuracy: 0.9209 - val_loss: nan - val_accuracy: 0.9223
# Epoch 18/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2528 - accuracy: 0.9255 - val_loss: nan - val_accuracy: 0.9268
# Epoch 19/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2426 - accuracy: 0.9286 - val_loss: nan - val_accuracy: 0.9289
# Epoch 20/20
# 108/108 [==============================] - 3s 24ms/step - loss: 0.2331 - accuracy: 0.9314 - val_loss: nan - val_accuracy: 0.9323

# %%
print('---- English Sentence ----')
print(' '.join(token_to_words(tmp_x[:1][0],english_tokenizer) ))
print()
translate(emb_bd_rnn_model.predict(tmp_x[:1]), preproc_french_sentences[:1])
# Out:
# ---- English Sentence ----
# new jersey is sometimes quiet during autumn and it is snowy in april
#
# ---- French Sentence ----
# new jersey est parfois calme pendant l' automne et il est neigeux en avril
#
# ---- Prediction ----
# new jersey est parfois calme en automne et il est neigeux en avril

# %% [markdown]
# ## Model 4
# Read this https://machinelearningmastery.com/encoder-decoder-long-short-term-memory-networks/

# %%
def model_final(input_shape, output_sequence_length, english_vocab_size, french_vocab_size):
    learning_rate = 6e-3
    embedding_size = 256
    units = 256
    
    model = Sequential()
    
    ########### ENCODER ###########
    
    model.add(Embedding(input_dim = english_vocab_size, output_dim = embedding_size, 
                           input_length= input_shape[1], name="Embedding_layer"))
    model.add(Bidirectional(LSTM(units, return_sequences=False), name='Bi_LSTM_Encoder'))
    
    ########### INTERMEDIARY ###########
    # Repeat Vector adjusts the shape of the Encoder output (2D) to the need of the Decoder (3D input).
    # We repeat the 2D vector over sequence_length times to produce the shape (batchsize, seq_length, num_units)
    model.add(RepeatVector(output_sequence_length, name='RepeatVector'))
    
    ########### DECODER ###########
    
    model.add(LSTM(units, return_sequences=True, name='LSTM_Decoder'))
    model.add(TimeDistributed(Dense(french_vocab_size, activation='softmax'), name='Dense'))

    
    model.compile(loss=sparse_categorical_crossentropy,
                  optimizer=Adam(learning_rate),
                  metrics=['accuracy'])
    
    return model

# %%
tmp_x = pad(preproc_english_sentences, max_french_sequence_length) # pad input sequence to output sequence length

# Train the neural network
final_model = model_final(
                        tmp_x.shape,
                        max_french_sequence_length,
                        english_vocab_size,
                        french_vocab_size)

final_model.summary()

final_model.fit(tmp_x, preproc_french_sentences, batch_size=1024, epochs=20, validation_split=0.2)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Embedding_layer (Embedding)  (None, 21, 256)          50944
#
#  Bi_LSTM_Encoder (Bidirectio  (None, 512)              1050624
#  nal)
#
#  RepeatVector (RepeatVector)  (None, 21, 512)          0
#
#  LSTM_Decoder (LSTM)         (None, 21, 256)           787456
#
#  Dense (TimeDistributed)     (None, 21, 344)           88408
#
# =================================================================
# Total params: 1,977,432
# Trainable params: 1,977,432
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 108/108 [==============================] - 15s 107ms/step - loss: 2.4671 - accuracy: 0.4782 - val_loss: nan - val_accuracy: 0.5608
# Epoch 2/20
# 108/108 [==============================] - 11s 98ms/step - loss: 1.5372 - accuracy: 0.5993 - val_loss: nan - val_accuracy: 0.6471
# Epoch 3/20
# 108/108 [==============================] - 11s 99ms/step - loss: 1.1799 - accuracy: 0.6784 - val_loss: nan - val_accuracy: 0.6800
# Epoch 4/20
# 108/108 [==============================] - 11s 99ms/step - loss: 0.9853 - accuracy: 0.7274 - val_loss: nan - val_accuracy: 0.7486
# Epoch 5/20
# 108/108 [==============================] - 11s 99ms/step - loss: 0.8105 - accuracy: 0.7706 - val_loss: nan - val_accuracy: 0.7962
# Epoch 6/20
# 108/108 [==============================] - 11s 99ms/step - loss: 0.6536 - accuracy: 0.8138 - val_loss: nan - val_accuracy: 0.8370
# Epoch 7/20
# 108/108 [==============================] - 11s 99ms/step - loss: 0.5206 - accuracy: 0.8494 - val_loss: nan - val_accuracy: 0.8686
# Epoch 8/20
# 108/108 [==============================] - 11s 99ms/step - loss: 0.4086 - accuracy: 0.8831 - val_loss: nan - val_accuracy: 0.8939
# Epoch 9/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.3535 - accuracy: 0.8992 - val_loss: nan - val_accuracy: 0.9144
# Epoch 10/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.2614 - accuracy: 0.9292 - val_loss: nan - val_accuracy: 0.9343
# Epoch 11/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.2135 - accuracy: 0.9448 - val_loss: nan - val_accuracy: 0.9485
# Epoch 12/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.1757 - accuracy: 0.9558 - val_loss: nan - val_accuracy: 0.9443
# Epoch 13/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.1534 - accuracy: 0.9615 - val_loss: nan - val_accuracy: 0.9616
# Epoch 14/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.1250 - accuracy: 0.9698 - val_loss: nan - val_accuracy: 0.9629
# Epoch 15/20
# 108/108 [==============================] - 11s 101ms/step - loss: 0.1067 - accuracy: 0.9744 - val_loss: nan - val_accuracy: 0.9713
# Epoch 16/20
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0952 - accuracy: 0.9772 - val_loss: nan - val_accuracy: 0.9721
# Epoch 17/20
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0878 - accuracy: 0.9784 - val_loss: nan - val_accuracy: 0.9745
# Epoch 18/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0759 - accuracy: 0.9816 - val_loss: nan - val_accuracy: 0.9774
# Epoch 19/20
# 108/108 [==============================] - 11s 101ms/step - loss: 0.0724 - accuracy: 0.9821 - val_loss: nan - val_accuracy: 0.9763
# Epoch 20/20
# 108/108 [==============================] - 11s 100ms/step - loss: 0.0818 - accuracy: 0.9783 - val_loss: nan - val_accuracy: 0.9772

# %%
print('---- English Sentence ----')
print(' '.join(token_to_words(tmp_x[:1][0],english_tokenizer) ))
print()
translate(final_model.predict(tmp_x[:1]), preproc_french_sentences[:1])
# Out:
# ---- English Sentence ----
# new jersey is sometimes quiet during autumn and it is snowy in april
#
# ---- French Sentence ----
# new jersey est parfois calme pendant l' automne et il est neigeux en avril
#
# ---- Prediction ----
# new jersey est parfois calme à l'automne et il est neigeux en avril
